# %% [markdown]
# # Projet Data Science

# %% [markdown]
# Tomás Mejia, Antoine Balannec, Alexandre Le Borgne, Sébastien Hierso

# %% [markdown]
# data datasoft: https://public.opendatasoft.com/explore/dataset/covid-19-pandemic-worldwide-data/export/?disjunctive.zone&disjunctive.category&refine.zone=France

# %% [markdown]
# data gouv: https://github.com/opencovid19-fr/data

# %%
import pandas as pd
import numpy as np

# %%
url="https://raw.githubusercontent.com/opencovid19-fr/data/master/dist/chiffres-cles.csv"
c=pd.read_csv(url)

# %%
df1 = pd.DataFrame(c)

df1
# Out:
#              date  granularite maille_code                  maille_nom  \
# 0      2020-01-24  departement      DEP-16                    Charente
# 1      2020-01-24  departement      DEP-17           Charente-Maritime
# 2      2020-01-24  departement      DEP-19                     Corrèze
# 3      2020-01-24  departement      DEP-23                      Creuse
# 4      2020-01-24  departement      DEP-24                    Dordogne
# ...           ...          ...         ...                         ...
# 27272  2020-09-30       region      REG-75          Nouvelle-Aquitaine
# 27273  2020-09-30       region      REG-76                   Occitanie
# 27274  2020-09-30       region      REG-84        Auvergne-Rhône-Alpes
# 27275  2020-09-30       region      REG-93  Provence-Alpes-Côte d'Azur
# 27276  2020-09-30       region      REG-94                       Corse
#
#        cas_confirmes  cas_ehpad  cas_confirmes_ehpad  cas_possibles_ehpad  \
# 0                0.0        NaN                  NaN                  NaN
# 1                0.0        NaN                  NaN                  NaN
# 2                0.0        NaN                  NaN                  NaN
# 3                0.0        NaN                  NaN                  NaN
# 4                0.0        NaN                  NaN                  NaN
# ...              ...        ...                  ...                  ...
# 27272            NaN        NaN                  NaN                  NaN
# 27273            NaN        NaN                  NaN                  NaN
# 27274            NaN        NaN                  NaN                  NaN
# 27275            NaN        NaN                  NaN                  NaN
# 27276            NaN        NaN                  NaN                  NaN
#
#         deces  deces_ehpad  reanimation  hospitalises  \
# 0         NaN          NaN          NaN           NaN
# 1         NaN          NaN          NaN           NaN
# 2         NaN          NaN          NaN           NaN
# 3         NaN          NaN          NaN           NaN
# 4         NaN          NaN          NaN           NaN
# ...       ...          ...          ...           ...
# 27272   500.0          NaN         56.0         317.0
# 27273   597.0          NaN        130.0         419.0
# 27274  1921.0          NaN        147.0         837.0
# 27275  1147.0          NaN        171.0         776.0
# 27276    65.0          NaN          4.0          26.0
#
#        nouvelles_hospitalisations  nouvelles_reanimations  gueris  depistes  \
# 0                             NaN                     NaN     NaN       NaN
# 1                             NaN                     NaN     NaN       NaN
# 2                             NaN                     NaN     NaN       NaN
# 3                             NaN                     NaN     NaN       NaN
# 4                             NaN                     NaN     NaN       NaN
# ...                           ...                     ...     ...       ...
# 27272                        17.0                     4.0  2754.0       NaN
# 27273                        56.0                    12.0  3714.0       NaN
# 27274                        74.0                    15.0  9513.0       NaN
# 27275                        71.0                    13.0  8096.0       NaN
# 27276                         4.0                     1.0   296.0       NaN
#
#                    source_nom  \
# 0      ARS Nouvelle-Aquitaine
# 1      ARS Nouvelle-Aquitaine
# 2      ARS Nouvelle-Aquitaine
# 3      ARS Nouvelle-Aquitaine
# 4      ARS Nouvelle-Aquitaine
# ...                       ...
# 27272          OpenCOVID19-fr
# 27273          OpenCOVID19-fr
# 27274          OpenCOVID19-fr
# 27275          OpenCOVID19-fr
# 27276          OpenCOVID19-fr
#
#                                               source_url source_archive  \
# 0      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 1      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 2      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 3      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# 4      https://www.nouvelle-aquitaine.ars.sante.fr/co...            NaN
# ...                                                  ...            ...
# 27272                                                NaN            NaN
# 27273                                                NaN            NaN
# 27274                                                NaN            NaN
# 27275                                                NaN            NaN
# 27276                                                NaN            NaN
#
#                     source_type
# 0      agences-regionales-sante
# 1      agences-regionales-sante
# 2      agences-regionales-sante
# 3      agences-regionales-sante
# 4      agences-regionales-sante
# ...                         ...
# 27272            opencovid19-fr
# 27273            opencovid19-fr
# 27274            opencovid19-fr
# 27275            opencovid19-fr
# 27276            opencovid19-fr
#
# [27277 rows x 20 columns]

# %%
c2 = pd.read_csv("datasets/covid-19-pandemic-worldwide-data-fr.csv")

df2 = pd.DataFrame(c2)
df2
# Out:
#                                                   Zone;Sub Zone;Category;Date;Count;Location
# France;French Guiana;Deaths;2020-04-03;0;3.9339                                     -53.1258
# France;French Guiana;Deaths;2020-04-16;0;3.9339                                     -53.1258
# France;French Guiana;Deaths;2020-03-20;0;3.9339                                     -53.1258
# France;French Guiana;Deaths;2020-04-17;0;3.9339                                     -53.1258
# France;French Guiana;Deaths;2020-07-21;39;3.9339                                    -53.1258
# ...                                                                                      ...
# France;Guadeloupe;Deaths;2020-09-24;42;16.265                                       -61.5510
# France;Guadeloupe;Deaths;2020-02-13;0;16.265                                        -61.5510
# France;Guadeloupe;Deaths;2020-06-01;14;16.265                                       -61.5510
# France;Guadeloupe;Deaths;2020-03-10;0;16.265                                        -61.5510
# France;Guadeloupe;Deaths;2020-04-02;6;16.265                                        -61.5510
#
# [8316 rows x 1 columns]
